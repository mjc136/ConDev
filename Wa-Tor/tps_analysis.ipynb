# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define paths to CSV files for each thread count
csv_paths = {
    "1 Thread": "SingleThread/tps_data.csv",
    "2 Threads": "TwoThread/tps_data.csv",
    "4 Threads": "FourThread/tps_data.csv",
    "8 Threads": "EightThread/tps_data.csv"
}

# Load the CSV data and plot
plt.figure(figsize=(12, 6))

for label, path in csv_paths.items():
    if os.path.exists(path):
        # Load the CSV file
        df = pd.read_csv(path)
        
        # Plot the TPS column
        plt.plot(df["Frame"], df["TPS"], label=label)
    else:
        print(f"File not found: {path}")

# Customize the plot
plt.xlabel("Frame")
plt.ylabel("TPS")
plt.title("TPS Comparison for Different Thread Counts")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
